# %%
import requests, json, time
import pandas as pd
from collections import Counter, defaultdict
import fitz
import re

# %%
do_read_from_web = True
do_read_from_cvs = not do_read_from_web
include_dois = True
include_arxiv = True

# %%
pdf_file_name = "/home/yoren/yumvd.Yandex.Disk/Yura/Personal/grants/DOE_progress_report_publications_2023_2026.pdf"

base_url = "https://inspirehep.net/api/literature"

exclude_collabs = []

# %%
pdf_path = pdf_file_name


# read all text
doc = fitz.open(pdf_path)
text = " ".join(page.get_text("text") for page in doc)

# --- normalize all hyphen / dash variants ---
dash_chars = [
    "\u00ad",  # soft hyphen
    "\u2010",  # hyphen
    "\u2011",  # non-breaking hyphen
    "\u2012",  # figure dash
    "\u2013",  # en dash
    "\u2014",  # em dash
    "\u2015",  # horizontal bar
    "\u2212",  # minus sign
]
for ch in dash_chars:
    text = text.replace(ch, "-")

# remove newlines inside DOIs
text = re.sub(r'\s*-\s*(?=\d)', '-', text)  # fix broken numeric segments
text = re.sub(r'\s*\n\s*', ' ', text)        # flatten newlines

# --- extract DOIs ---
doi_pattern = r'10\.\d{4,9}/[A-Za-z0-9.\-()/]+'
dois = sorted(set(re.findall(doi_pattern, text)))

# --- extract arXiv IDs ---
# captures both old and new formats: e.g. arXiv:2509.13497 or arXiv:hep-ph/0501234
arxiv_pattern = r'arXiv:\s*[A-Za-z\-\.]*\d{4,5}\.\d{4,5}'
arxivs = sorted(set(re.findall(arxiv_pattern, text)))

# --- clean whitespace ---
arxivs = [a.replace(" ", "") for a in arxivs]

print(f"Found {len(dois)} DOIs and {len(arxivs)} arXiv IDs\n")
print("DOIs:")
for d in dois:
    print(" ", d)

print("\nArXiv preprints:")
for a in arxivs:
    print(" ", a)
# Out:
# Found 26 DOIs and 9 arXiv IDs
#
# DOIs:
#   10.1007/JHEP08(2025)075
#   10.1016/j.nima.2024.170127
#   10.1016/j.nima.2024.170171
#   10.1016/j.physletb.2023.138101
#   10.1088/1748-0221/18/06/C06024
#   10.1103/6pmd-6dwr
#   10.1103/PhysRevC.107.014907
#   10.1103/PhysRevC.107.024907
#   10.1103/PhysRevC.107.024914
#   10.1103/PhysRevC.109.044912
#   10.1103/PhysRevC.109.054910
#   10.1103/PhysRevC.110.044901
#   10.1103/PhysRevC.110.064905
#   10.1103/PhysRevC.110.064909
#   10.1103/PhysRevD.107.052012
#   10.1103/PhysRevD.107.112004
#   10.1103/PhysRevD.108.072016
#   10.1103/PhysRevLett.130.251901
#   10.1103/PhysRevLett.134.022302
#   10.1103/h8d5-swg6
#   10.1103/hpm9-
#   10.1103/ptpm-jtt8
#   10.1140/epjc/s10052-024-12987-0
#   10.1140/epjc/s10052-024-13003-1
#   10.1140/epjc/s10052-024-13115-8
#   10.1140/epjc/s10052-024-13416-y
#
# ArXiv preprints:
#   arXiv:2303.17254
#   arXiv:2409.03728
#   arXiv:2411.11942
#   arXiv:2412.08682
#   arXiv:2412.14092
#   arXiv:2504.02955
#   arXiv:2507.04463
#   arXiv:2507.04896
#   arXiv:2509.13497

# %%
#if doi finishes with dashes, fix them
for i, d in enumerate(dois):
    if d.endswith('-'):
        print(i, d)
        d += 'qfp6'
    dois[i] = d

dois.append('10.1103/PhysRevC.109.044907')  # manual add
# Out:
# 20 10.1103/hpm9-

# %%
records = []

# combine all identifiers
ids = []
if include_dois:
    ids.extend(dois)
if include_arxiv:
    ids.extend(arxivs)

for identifier in ids:
    # Detect whether it's a DOI or arXiv
    if identifier.lower().startswith("10."):
        query = f'doi:"{identifier}"'
    elif "arxiv:" in identifier.lower():
        query = f'arxiv_eprints.value:"{identifier.split(":")[-1]}"'
    else:
        continue

    params = {"q": query, "size": 1}

    try:
        r = requests.get(base_url, params=params, timeout=60)
        r.raise_for_status()
        data = r.json()
    except json.JSONDecodeError:
        print(f"⚠️ JSONDecodeError for {identifier}, skipping...")
        continue
    except requests.RequestException as e:
        print(f"❌ Request failed for {identifier}: {e}")
        continue

    hits = data.get("hits", {}).get("hits", [])
    if not hits:
        print(f"❌ No record found for {identifier}")
        continue

    for hit in hits:
        m = hit.get("metadata", {})

        # --- collaborations ---
        collabs = [c.get("value", "") for c in m.get("collaborations", [])]
        if any(c in exclude_collabs for c in collabs):
            continue

        # --- publication year ---
        pub_year = None
        for pub in m.get("publication_info", []):
            y = pub.get("year")
            if y and str(y).isdigit():
                pub_year = int(y)
                break
        if not pub_year:
            y = str(m.get("preprint_date", ""))[:4]
            pub_year = int(y) if y.isdigit() else None

        rec = {
            "Title": m.get("titles", [{}])[0].get("title", ""),
            "Date": pub_year,
            "DOI": m.get("dois", [{}])[0].get("value", ""),
            "ArXivID": m.get("arxiv_eprints", [{}])[0].get("value", ""),
            "Collaboration": ", ".join(c for c in collabs if c),
            "Citations": m.get("citation_count", 0),
            "DocumentType": ", ".join(m.get("document_type", [])),
            "Refereed": m.get("refereed", False),
            "Categories": ", ".join(cat.get("term", "") for cat in m.get("inspire_categories", [])),
            "ControlNumber": m.get("control_number"),
        }

        author_list = []
        for a in m.get("authors", []):
            affs = [
                aff.get("value", "")
                for aff in (a.get("affiliations", []) + a.get("raw_affiliations", []))
                if "value" in aff
            ]
            author_list.append({
                "name": a.get("full_name", ""),
                "affiliations": affs
            })
        rec["Authors"] = author_list

        records.append(rec)

    print(f"✅ Fetched metadata for: {identifier}")
    time.sleep(0.3)

print(f"\n✅ Total records collected: {len(records)}")
# Out:
# ✅ Fetched metadata for: 10.1007/JHEP08(2025)075
# ✅ Fetched metadata for: 10.1016/j.nima.2024.170127
# ✅ Fetched metadata for: 10.1016/j.nima.2024.170171
# ✅ Fetched metadata for: 10.1016/j.physletb.2023.138101
# ✅ Fetched metadata for: 10.1088/1748-0221/18/06/C06024
# ✅ Fetched metadata for: 10.1103/6pmd-6dwr
# ✅ Fetched metadata for: 10.1103/PhysRevC.107.014907
# ✅ Fetched metadata for: 10.1103/PhysRevC.107.024907
# ✅ Fetched metadata for: 10.1103/PhysRevC.107.024914
# ✅ Fetched metadata for: 10.1103/PhysRevC.109.044912
# ✅ Fetched metadata for: 10.1103/PhysRevC.109.054910
# ✅ Fetched metadata for: 10.1103/PhysRevC.110.044901
# ✅ Fetched metadata for: 10.1103/PhysRevC.110.064905
# ✅ Fetched metadata for: 10.1103/PhysRevC.110.064909
# ✅ Fetched metadata for: 10.1103/PhysRevD.107.052012
# ✅ Fetched metadata for: 10.1103/PhysRevD.107.112004
# ✅ Fetched metadata for: 10.1103/PhysRevD.108.072016
# ✅ Fetched metadata for: 10.1103/PhysRevLett.130.251901
# ✅ Fetched metadata for: 10.1103/PhysRevLett.134.022302
# ✅ Fetched metadata for: 10.1103/h8d5-swg6
# ✅ Fetched metadata for: 10.1103/hpm9-qfp6
# ✅ Fetched metadata for: 10.1103/ptpm-jtt8
# ✅ Fetched metadata for: 10.1140/epjc/s10052-024-12987-0
# ✅ Fetched metadata for: 10.1140/epjc/s10052-024-13003-1
# ✅ Fetched metadata for: 10.1140/epjc/s10052-024-13115-8
# ✅ Fetched metadata for: 10.1140/epjc/s10052-024-13416-y
# ✅ Fetched metadata for: 10.1103/PhysRevC.109.044907
# ✅ Fetched metadata for: arXiv:2303.17254
# ✅ Fetched metadata for: arXiv:2409.03728
# ✅ Fetched metadata for: arXiv:2411.11942
# ✅ Fetched metadata for: arXiv:2412.08682
# ✅ Fetched metadata for: arXiv:2412.14092
# ✅ Fetched metadata for: arXiv:2504.02955
# ✅ Fetched metadata for: arXiv:2507.04463
# ✅ Fetched metadata for: arXiv:2507.04896
# ✅ Fetched metadata for: arXiv:2509.13497
#
# ✅ Total records collected: 36

# %%
if do_read_from_web:   
    # Save as CSV
    df = pd.DataFrame(records)
    df["Authors"] = df["Authors"].apply(json.dumps)  # store list of dicts safely
    df.to_csv("inspire_doi_metadata_full.csv", index=False)
    print("💾 Saved to inspire_doi_metadata_full.csv")
# Out:
# 💾 Saved to inspire_doi_metadata_full.csv

# %%
if do_read_from_cvs:
    import pandas as pd, ast
    df = pd.read_csv("inspire_doi_metadata_full.csv")

    # Convert back to list of dicts
    df["Authors"] = df["Authors"].apply(ast.literal_eval)
    records = df.to_dict(orient="records")

    # Now this works again:
    #for a in records[0]["Authors"]:
    #    print(a["name"], a["affiliations"])

# %%
for rec in records:
    year_str = str(rec.get("Date", ""))[:4]
    if year_str.isdigit() and int(year_str) < 2023:
        print(f"{year_str}: {rec['Title']}")

# %%
def classify_doc_type(row):
    doi = str(row.get("DOI", "")).strip()
    doc_type = str(row.get("DocumentType", "")).lower()

    # --- pattern-based inference ---
    if any(tag in doi.lower() for tag in ["physrevlett", "physletb", "plb"]):
        inferred = "letter"
    elif re.match(r"^10\.1103/[A-Za-z0-9\-]{6,10}$", doi) and not re.search(r"physrev", doi, re.IGNORECASE):
        # short hashed DOI-like placeholder → preprint
        inferred = "preprint"
    elif "conference" in doc_type or "proceeding" in doc_type or "jphysconf" in doi.lower():
        inferred = "conference paper"
    else:
        inferred = "article"

    if not doc_type or doc_type in ["", "article", "paper"]:
        return inferred
    return doc_type

df["DocumentType_inferred"] = df.apply(classify_doc_type, axis=1)

print("✅ DOI classification preview:\n")
for doi, typ in zip(df["DOI"], df["DocumentType_inferred"]):
    print(f"{doi:50} → {typ}")
# Out:
# ✅ DOI classification preview:
#
# 10.1007/JHEP08(2025)075                            → article
# 10.1016/j.nima.2024.170127                         → article
# 10.1016/j.nima.2024.170171                         → article
# 10.1016/j.physletb.2023.138101                     → letter
# 10.1088/1748-0221/18/06/C06024                     → conference paper
# 10.1103/6pmd-6dwr                                  → preprint
# 10.1103/PhysRevC.107.014907                        → article
# 10.1103/PhysRevC.107.024907                        → article
# 10.1103/PhysRevC.107.024914                        → article
# 10.1103/PhysRevC.109.044912                        → article
# 10.1103/PhysRevC.109.054910                        → article
# 10.1103/PhysRevC.110.044901                        → article
# 10.1103/PhysRevC.110.064905                        → article
# 10.1103/PhysRevC.110.064909                        → article
# 10.1103/PhysRevD.107.052012                        → article
# 10.1103/PhysRevD.107.112004                        → article
# 10.1103/PhysRevD.108.072016                        → article
# 10.1103/PhysRevLett.130.251901                     → letter
# 10.1103/PhysRevLett.134.022302                     → letter
# 10.1103/h8d5-swg6                                  → preprint
# 10.1103/hpm9-qfp6                                  → preprint
# 10.1103/ptpm-jtt8                                  → preprint
# 10.1140/epjc/s10052-024-12987-0                    → article
# 10.1140/epjc/s10052-024-13003-1                    → article
# 10.1140/epjc/s10052-024-13115-8                    → article
# 10.1140/epjc/s10052-024-13416-y                    → article
# 10.1103/PhysRevC.109.044907                        → article
#                                                    → article
# 10.1103/6vqj-wdfr                                  → preprint
#                                                    → article
#                                                    → article
#                                                    → article
#                                                    → article
#                                                    → article
#                                                    → article
#                                                    → article

# %%
#printing titles of articel whih DocumentType_inferred is conference paper
for index, row in df.iterrows():
    if row["DocumentType_inferred"] == "conference paper":
        print(row["Title"])
# Out:
# The effects of a passive Bi-Polar Grid (BPG) on Ion Back-Flow (IBF) and resolution

# %%
df["Collaboration"].value_counts()
# Out:
# Collaboration
# PHENIX        21
#                7
# H1             5
# sPHENIX        2
# CERES NA45     1
# Name: count, dtype: int64

# %%
# Keywords that identify SBU affiliations
sbu_keys = ["stony brook", "suny stony brook", "state univ. of new york","suny","yitp"]

# %%
author_counter = Counter()
author_papers = {}  # optional: to track which papers belong to each author

for rec in records:
    title = rec["Title"]
    for author in rec["Authors"]:
        affs = author.get("affiliations", [])
        # Check if any affiliation matches SBU
        if any(any(key in aff.lower() for key in sbu_keys) for aff in affs):
            name = author["name"]
            author_counter[name] += 1
            author_papers.setdefault(name, []).append(title)

sbu_authors = author_counter
print(f"Found {len(author_counter)} authors with SBU affiliation")
# Out:
# Found 117 authors with SBU affiliation

# %%
authors_df = pd.DataFrame(
    author_counter.items(),
    columns=["Author", "Num_SBU_Papers"]
).sort_values("Num_SBU_Papers", ascending=False)

authors_df.head(20)
# Out:
#              Author  Num_SBU_Papers
# 6         Drees, A.              30
# 27         Park, S.              26
# 24    Deshpande, A.              26
# 25          Gal, C.              26
# 4         David, G.              24
# 3       Corliss, R.              23
# 7          Esha, R.              23
# 9         Firak, D.              23
# 5       Dehmelt, K.              22
# 10         Garg, P.              22
# 61       Sharma, D.              21
# 56     Novitzky, N.              21
# 44           Ji, Z.              21
# 42    Hemmick, T.K.              21
# 66  Yamaguchi, Y.L.              21
# 36       Doomra, V.              21
# 62          Sun, J.              20
# 64    Taranenko, A.              20
# 59     Reynolds, D.              20
# 41        Hanks, J.              20

# %%
import re
from collections import defaultdict

def get_last_name(full_name):
    """Extract surname from 'Last, First' or 'First Last' formats."""
    if not full_name:
        return ""
    name = re.sub(r"[,]", " ", full_name).strip()
    parts = [p for p in name.split() if p]
    if not parts:
        return ""
    last = parts[0] if "," in full_name else parts[-1]
    last = re.sub(r"[^A-Za-z\-]", "", last).lower().strip()
    return last

def get_first_initial(full_name):
    """Return the first letter of the given name part (after comma or first token)."""
    if not full_name:
        return ""
    name = re.sub(r"[,]", " ", full_name).strip()
    parts = [p for p in name.split() if p]
    if not parts:
        return ""
    # if format 'Last, First'
    if "," in full_name:
        if len(parts) > 1:
            token = re.sub(r"[^A-Za-z]", "", parts[1])
            return token[0].lower() if token else ""
    # if 'First Last'
    elif len(parts) > 1:
        token = re.sub(r"[^A-Za-z]", "", parts[0])
        return token[0].lower() if token else ""
    return ""

# ------------------------------------------------------
# Combine authors: same last name + same first initial
# ------------------------------------------------------
author_groups = defaultdict(list)

for name in sorted(sbu_authors):
    last = get_last_name(name)
    first_init = get_first_initial(name)
    if last:
        key = f"{last}_{first_init}"  # e.g., "esha_r", "chen_c"
        author_groups[key].append(name)

# Show groups that contain multiple variants
for key, names in sorted(author_groups.items()):
    if len(names) > 1:
        print(f"{key}: {names}")

print(f"\nTotal unique (last+first-initial) combinations: {len(author_groups)}")
# Out:
# corliss_r: ['Corliss, R.', 'Corliss, Ross']
# david_g: ['David, G.', 'David, Gabor']
# esha_r: ['Esha, R.', 'Esha, Roli']
# hemmick_t: ['Hemmick, T.', 'Hemmick, T.K.', 'Hemmick, Thomas']
# jacak_b: ['Jacak, B.', 'Jacak, B.V.']
# ramasubramanian_n: ['Ramasubramanian, N.', 'Ramasubramanian, N.V.']
# shulga_e: ['Shulga, E.', 'Shulga, Evgeny']
#
# Total unique (last+first-initial) combinations: 109

# %%
sbu_keys = [
    "stony brook",
    "suny stony brook",
    "state univ. of new york",
    "yitp",
    "yitp, stony brook",
    "stony brook u.",
    "suny, stony brook",
    "suny"
]

# %%
# ----------------------------------------------------
# Build unified author keys (last + first initial)
# ----------------------------------------------------
author_variants = defaultdict(list)
for name in sorted(sbu_authors):
    last = get_last_name(name)
    first_init = get_first_initial(name)
    if not last:
        continue
    key = f"{last}_{first_init}"
    author_variants[key].append(name)

sbu_authors_last = set(author_variants.keys())
print(f"Unified to {len(sbu_authors_last)} unique (last+first-initial) authors for DOE-matched list.")

# ----------------------------------------------------
# Count 2023+ SBU-affiliated papers for those authors
# ----------------------------------------------------
def year_from_record(rec):
    y = str(rec.get("Date", ""))[:4]
    return int(y) if y.isdigit() else None

records_recent = [r for r in records if (year_from_record(r) and year_from_record(r) >= 2023)]
print(f"Total records from 2023+: {len(records_recent)}")

author_recent_sbu = defaultdict(list)

for rec in records_recent:
    doi = rec.get("DOI", "").strip() or f"no_doi_{rec.get('Title','')[:120]}"
    for a in rec.get("Authors", []):
        last = get_last_name(a["name"])
        first_init = get_first_initial(a["name"])
        key = f"{last}_{first_init}"
        if key not in sbu_authors_last:
            continue

        # Collect all affiliation strings safely
        affs = []
        for aff_obj in (a.get("affiliations", []) + a.get("raw_affiliations", [])):
            if isinstance(aff_obj, dict) and "value" in aff_obj:
                affs.append(aff_obj["value"])
            elif isinstance(aff_obj, str):
                affs.append(aff_obj)

        # Match against known SBU patterns
        aff_joined = " ".join(affs).lower()
        if any(k.lower() in aff_joined for k in sbu_keys):
            author_recent_sbu[key].append(rec)

# ----------------------------------------------------
# Build DataFrame with classification by DOI pattern
# ----------------------------------------------------
def infer_doc_type(doi, doc_type):
    doi = (doi or "").lower()
    doc_type = (doc_type or "").lower()

    if any(tag in doi for tag in ["physrevlett", "physletb", "plb"]):
        return "letter"
    elif re.match(r"^10\.1103/[A-Za-z0-9\-]{6,10}$", doi) and not re.search(r"physrev", doi, re.IGNORECASE):
        return "preprint"
    elif "conference" in doc_type or "proceeding" in doc_type or "jphysconf" in doi:
        return "conference"
    return "article"

rows = []
for key, recs in author_recent_sbu.items():
    # Build a dictionary keyed by DOI, so duplicates collapse automatically
    unique_by_doi = {}

    for r in recs:
        doi = r.get("DOI", f"no_doi_{r.get('Title','')[:120]}")
        unique_by_doi[doi] = r   # overwrite duplicates safely

    # classify unique DOIs only
    num_letters = 0
    num_peer_reviewed = 0
    num_preprints = 0

    for doi, r in unique_by_doi.items():
        inferred = infer_doc_type(r.get("DOI"), r.get("DocumentType"))
        if inferred == "letter":
            num_letters += 1
        elif inferred in ["preprint", "preprint (possibly)"]:
            num_preprints += 1
        elif inferred == "article":
            num_peer_reviewed += 1

    unique_dois = set(unique_by_doi.keys())

    rows.append({
        "AuthorKey": key,
        "FullNames": ", ".join(sorted(set(author_variants.get(key, [])))),
        "Num_SBU_Papers_since2023": len(unique_dois),
        "Num_Letters": num_letters,
        "Num_PeerReviewed": num_peer_reviewed,
        "Num_Preprints": num_preprints,
        "DOIs": "; ".join(sorted(unique_dois))
    })

authors_recent_df = pd.DataFrame(rows).sort_values("Num_SBU_Papers_since2023", ascending=False)
authors_recent_df.to_csv("selected_authors_sbu_since2023.csv", index=False)

print(f"✅ Saved {len(authors_recent_df)} authors with SBU affiliation since 2023.")
authors_recent_df.head(40)
# Out:
# Unified to 109 unique (last+first-initial) authors for DOE-matched list.
# Total records from 2023+: 36
# ✅ Saved 109 authors with SBU affiliation since 2023.
#         AuthorKey                                    FullNames  \
# 6         drees_a                                    Drees, A.
# 21          gal_c                                      Gal, C.
# 23         park_s                                     Park, S.
# 11      hemmick_t  Hemmick, T., Hemmick, T.K., Hemmick, Thomas
# 20    deshpande_a                                Deshpande, A.
# 3       corliss_r                   Corliss, R., Corliss, Ross
# 4         david_g                      David, G., David, Gabor
# 7          esha_r                         Esha, R., Esha, Roli
# 9         firak_d                                    Firak, D.
# 10         garg_p                                     Garg, P.
# 39           ji_z                                       Ji, Z.
# 5       dehmelt_k                                  Dehmelt, K.
# 61    yamaguchi_y                              Yamaguchi, Y.L.
# 32       doomra_v                                   Doomra, V.
# 51     novitzky_n                                 Novitzky, N.
# 56       sharma_d                                   Sharma, D.
# 38        jacak_b                       Jacak, B., Jacak, B.V.
# 37        hanks_j                                    Hanks, J.
# 44          lee_s                                    Lee, S.H.
# 43        kline_p                                    Kline, P.
# 54     reynolds_d                                 Reynolds, D.
# 59    taranenko_a                                Taranenko, A.
# 57          sun_j                                      Sun, J.
# 42  khachatryan_v                              Khachatryan, V.
# 52    perezlara_c                              PerezLara, C.E.
# 31         dion_a                                     Dion, A.
# 33          fan_w                                      Fan, W.
# 34        feege_n                                    Feege, N.
# 35           ge_h                                       Ge, H.
# 60       yalcin_s                                   Yalcin, S.
# 27    ajitanand_n                              Ajitanand, N.N.
# 28      apadula_n                                  Apadula, N.
# 29      bannier_b                                  Bannier, B.
# 30        canoa_r                              Canoa Roman, V.
# 50         mwai_a                                     Mwai, A.
# 46       manion_a                                   Manion, A.
# 53        petti_r                                    Petti, R.
# 22       mondal_m                                 Mondal, M.M.
# 55  sahlmueller_b                              Sahlmueller, B.
# 65        giles_m                                    Giles, M.
#
#     Num_SBU_Papers_since2023  Num_Letters  Num_PeerReviewed  Num_Preprints  \
# 6                         25            3                17              5
# 21                        22            3                15              4
# 23                        22            3                15              4
# 11                        22            2                14              5
# 20                        22            3                15              4
# 3                         21            2                14              5
# 4                         21            2                14              5
# 7                         21            2                14              5
# 9                         20            2                13              5
# 10                        19            2                11              5
# 39                        18            2                12              4
# 5                         18            2                11              5
# 61                        18            2                12              4
# 32                        18            2                12              4
# 51                        18            2                12              4
# 56                        18            2                12              4
# 38                        17            2                12              3
# 37                        17            1                12              4
# 44                        17            2                12              3
# 43                        17            1                12              4
# 54                        17            1                12              4
# 59                        17            2                12              3
# 57                        17            1                12              4
# 42                        17            2                11              4
# 52                        16            2                10              4
# 31                        16            1                11              4
# 33                        16            2                10              4
# 34                        15            2                 9              4
# 35                        15            2                 9              4
# 60                        14            1                 9              4
# 27                        13            1                 9              3
# 28                        13            1                 9              3
# 29                        13            1                 9              3
# 30                        13            2                 9              2
# 50                        13            1                 9              3
# 46                        13            1                 9              3
# 53                        13            1                 9              3
# 22                        12            3                 9              0
# 55                        12            0                 9              3
# 65                        12            2                10              0
#
#                                                  DOIs
# 6   ; 10.1007/JHEP08(2025)075; 10.1016/j.physletb....
# 21  ; 10.1016/j.physletb.2023.138101; 10.1103/6pmd...
# 23  ; 10.1016/j.physletb.2023.138101; 10.1103/6pmd...
# 11  ; 10.1007/JHEP08(2025)075; 10.1016/j.nima.2024...
# 20  ; 10.1016/j.physletb.2023.138101; 10.1103/6pmd...
# 3   ; 10.1007/JHEP08(2025)075; 10.1016/j.nima.2024...
# 4   ; 10.1007/JHEP08(2025)075; 10.1016/j.nima.2024...
# 7   ; 10.1007/JHEP08(2025)075; 10.1103/6pmd-6dwr; ...
# 9   ; 10.1007/JHEP08(2025)075; 10.1103/6pmd-6dwr; ...
# 10  ; 10.1007/JHEP08(2025)075; 10.1088/1748-0221/1...
# 39  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 5   ; 10.1007/JHEP08(2025)075; 10.1103/6pmd-6dwr; ...
# 61  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 32  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 51  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 56  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 38  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 37  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 44  ; 10.1103/6pmd-6dwr; 10.1103/PhysRevC.107.0149...
# 43  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 54  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 59  ; 10.1103/6pmd-6dwr; 10.1103/PhysRevC.107.0149...
# 57  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 42  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 52  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 31  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 33  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 34  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 35  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 60  ; 10.1103/6pmd-6dwr; 10.1103/6vqj-wdfr; 10.110...
# 27  ; 10.1103/6pmd-6dwr; 10.1103/PhysRevC.107.0149...
# 28  ; 10.1103/6pmd-6dwr; 10.1103/PhysRevC.107.0149...
# 29  ; 10.1103/6pmd-6dwr; 10.1103/PhysRevC.107.0149...
# 30  10.1103/6pmd-6dwr; 10.1103/PhysRevC.107.014907...
# 50  ; 10.1103/6pmd-6dwr; 10.1103/PhysRevC.107.0149...
# 46  ; 10.1103/6pmd-6dwr; 10.1103/PhysRevC.107.0149...
# 53  ; 10.1103/6pmd-6dwr; 10.1103/PhysRevC.107.0149...
# 22  10.1016/j.physletb.2023.138101; 10.1103/PhysRe...
# 55  ; 10.1103/6pmd-6dwr; 10.1103/PhysRevC.107.0149...
# 65  ; 10.1103/PhysRevC.107.014907; 10.1103/PhysRev...

# %%
target = "hemmick_t"  # author key to focus on (lastname_firstinitial)

for rec in records_recent:
    for a in rec["Authors"]:
        key = f"{get_last_name(a['name'])}_{get_first_initial(a['name'])}"
        if key == target:
            affs = []
            for aff in a.get("affiliations", []) + a.get("raw_affiliations", []):
                if isinstance(aff, dict) and "value" in aff:
                    affs.append(aff["value"])
                elif isinstance(aff, str):
                    affs.append(aff)
            aff_joined = " ".join(affs).lower()
            match = any(k.lower() in aff_joined for k in sbu_keys)
            print(
                f"{a['name']:25} | "
                f"{'✅ match' if match else '❌ missing'} | "
                f"{rec.get('Title', '')[:80]}"
            )
            if not match:
                print("   affiliations:", affs)
# Out:
# Hemmick, T.               | ✅ match | Measurement of charged hadron multiplicity in Au+Au collisions at $ \sqrt{{\text
# Hemmick, Thomas           | ✅ match | Fast spark-detection system for GEM detectors
# Hemmick, T.               | ✅ match | The effects of a passive Bi-Polar Grid (BPG) on Ion Back-Flow (IBF) and resoluti
# Hemmick, T.K.             | ✅ match | Measurement of elliptic flow of <math><mrow><mi>J</mi><mo>/</mo><mi>ψ</mi></mrow
# Hemmick, T.K.             | ✅ match | Measurement of <math><mi>ϕ</mi></math>-meson production in <math><mrow><mi>Cu</m
# Hemmick, T.K.             | ✅ match | Measurements of second-harmonic Fourier coefficients from azimuthal anisotropies
# Hemmick, T.K.             | ✅ match | Low-<math><msub><mi>p</mi><mi>T</mi></msub></math> direct-photon production in <
# Hemmick, T.K.             | ✅ match | Nonprompt direct-photon production in <math><mrow><mtext>Au</mtext><mo>+</mo><mt
# Hemmick, T.K.             | ✅ match | Identified charged-hadron production in <math><mrow><mi>p</mi><mo>+</mo><mi>Al</
# Hemmick, T.K.             | ✅ match | Jet modification via <math><msup><mi>π</mi><mn>0</mn></msup></math>-hadron corre
# Hemmick, T.K.             | ✅ match | Centrality dependence of Lévy-stable two-pion Bose-Einstein correlations in <mat
# Hemmick, T.K.             | ✅ match | Improving constraints on gluon spin-momentum correlations in transversely polari
# Hemmick, T.K.             | ✅ match | Transverse single-spin asymmetry of midrapidity <math display="inline"><msup><mi
# Hemmick, T.K.             | ✅ match | Transverse single-spin asymmetry of charged hadrons at forward and backward rapi
# Hemmick, T.K.             | ✅ match | Measurement of Direct-Photon Cross Section and Double-Helicity Asymmetry at <mat
# Hemmick, T.K.             | ✅ match | Disentangling Centrality Bias and Final-State Effects in the Production of High-
# Hemmick, T.               | ✅ match | Measurement of the transverse energy density in <math><mrow><mi>Au</mi><mo>+</mo
# Hemmick, T.K.             | ✅ match | Measurement of inclusive jet cross section and substructure in <math display="in
# Hemmick, T.K.             | ✅ match | Measurements at forward rapidity of elliptic flow of charged hadrons and open-he
# Hemmick, T.K.             | ✅ match | Charm- and bottom-quark production in Au+Au collisions at <math><mrow><msqrt><ms
# Hemmick, T.K.             | ✅ match | Multiplicity dependent <math display="inline"><mi>J</mi><mo>/</mo><mi>ψ</mi></ma
# Hemmick, T.K.             | ✅ match | Azimuthal anisotropy of direct photons in Au$+$Au collisions at $\sqrt{s_{_{NN}}
# Hemmick, T.K.             | ✅ match | Low-mass vector-meson production at forward rapidity in $p$$+$$p$ and Au$+$Au co
# Hemmick, T.K.             | ✅ match | Cross sections of $\eta$ mesons in $p$ $+$ $p$ collisions at forward rapidity at
# Hemmick, T.K.             | ✅ match | Transverse single-spin asymmetry of forward $η$ mesons in $p^{\uparrow}+ p$ coll

# %%
import requests, json

r = requests.get("https://inspirehep.net/api/literature/2645172")
m = r.json()["metadata"]

# print the entire metadata nicely formatted
print(json.dumps(m, indent=2))
# Out:
# {
#   "citation_count": 23,
#   "citation_count_without_self_citations": 9,
#   "publication_info": [
#     {
#       "year": 2025,
#       "artid": "022302",
#       "material": "publication",
#       "journal_issue": "2",
#       "journal_title": "Phys.Rev.Lett.",
#       "journal_record": {
#         "$ref": "https://inspirehep.net/api/journals/1214495"
#       },
#       "journal_volume": "134",
#       "pubinfo_freetext": "Phys. Rev. Lett. 134, 022302 (2025)"
#     }
#   ],
#   "core": true,
#   "dois": [
#     {
#       "value": "10.1103/PhysRevLett.134.022302",
#       "source": "APS",
#       "material": "publication"
#     },
#     {
#       "value": "10.1103/PhysRevLett.134.022302",
#       "source": "arXiv",
#       "material": "publication"
#     }
#   ],
#   "urls": [
#     {
#       "value": "https://www.bnl.gov/newsroom/news.php?a=122267",
#       "description": "Brookhaven News article"
#     }
#   ],
#   "titles": [
#     {
#       "title": "Disentangling Centrality Bias and Final-State Effects in the Production of High-<math display=\"inline\"><mrow><msub><mrow><mi>p</mi></mrow><mrow><mi>T</mi></mrow></msub></mrow></math> Neutral Pions Using Direct Photon in <math display=\"inline\"><mrow><mi>d</mi><mo>+</mo><mi>Au</mi></mrow></math> Collisions at <math display=\"inline\"><mrow><msqrt><mrow><msub><mrow><mi>s</mi></mrow><mrow><mi>N</mi><mi>N</mi></mrow></msub></mrow></msqrt><mo>=</mo><mn>200</mn><mtext>\u2009</mtext><mtext>\u2009</mtext><mi>GeV</mi></mrow></math>",
#       "source": "APS"
#     },
#     {
#       "title": "Disentangling centrality bias and final-state effects in the production of high-$p_T$$\\pi^0$ using direct $\\gamma$ in $d$$+$Au collisions at $\\sqrt{s_{_{NN}}}=200$ GeV",
#       "source": "arXiv"
#     }
#   ],
#   "$schema": "https://inspirehep.net/schemas/records/hep.json",
#   "authors": [
#     {
#       "uuid": "d1f5b7d0-b785-4e30-9ba5-9e57712acb34",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/2575615"
#       },
#       "full_name": "Abdulameer, N.J.",
#       "affiliations": [
#         {
#           "value": "Debrecen U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/911686"
#           }
#         }
#       ],
#       "signature_block": "ABDALANARn",
#       "raw_affiliations": [
#         {
#           "value": "Debrecen University, H-4010 Debrecen, Egyetem t\u00e9r 1, Hungary",
#           "source": "APS"
#         },
#         {
#           "value": "HUN-REN ATOMKI, H-4026 Debrecen, Bem t\u00e9r 18/c, Hungary",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "5381259b-ce7c-46a3-b577-11d9d19f977e",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1883776"
#       },
#       "full_name": "Acharya, U.",
#       "affiliations": [
#         {
#           "value": "Georgia State U., Atlanta",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/1275736"
#           }
#         }
#       ],
#       "signature_block": "ACARu",
#       "raw_affiliations": [
#         {
#           "value": "Georgia State University, Atlanta, Georgia 30303, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/03qt6ba18",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "971a0d3e-4ef7-4939-8995-4ca60fce98dd",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1033307"
#       },
#       "full_name": "Aidala, C.",
#       "affiliations": [
#         {
#           "value": "Michigan U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903007"
#           }
#         }
#       ],
#       "signature_block": "ADALc",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics, University of Michigan, Ann Arbor, Michigan 48109-1040, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "1b59ff6c-5584-4e93-b32f-f07ebfe90d5b",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1018785"
#       },
#       "full_name": "Akiba, Y.",
#       "affiliations": [
#         {
#           "value": "Nishina Ctr., RIKEN",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/911022"
#           }
#         },
#         {
#           "value": "RIKEN BNL",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/907483"
#           }
#         }
#       ],
#       "signature_block": "ACABy",
#       "raw_affiliations": [
#         {
#           "value": "RIKEN BNL Research Center, Brookhaven National Laboratory, Upton, New York 11973-5000, USA",
#           "source": "APS"
#         },
#         {
#           "value": "RIKEN Nishina Center for Accelerator-Based Science, Wako, Saitama 351-0198, Japan",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/02ex6cf31",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "ffc89da3-accb-42bc-8778-58121eb33ca4",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1022030"
#       },
#       "full_name": "Alfred, M.",
#       "affiliations": [
#         {
#           "value": "Howard U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903709"
#           }
#         }
#       ],
#       "signature_block": "ALFRADm",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Howard University, Washington, DC 20059, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "8aeb9177-9149-43e5-b86b-82cf3e6f6df8",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1068381"
#       },
#       "full_name": "Aoki, K.",
#       "affiliations": [
#         {
#           "value": "KEK, Tsukuba",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902916"
#           }
#         },
#         {
#           "value": "JAERI, Tokai",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903713"
#           }
#         }
#       ],
#       "signature_block": "ACk",
#       "raw_affiliations": [
#         {
#           "value": "KEK, High Energy Accelerator Research Organization, Tsukuba, Ibaraki 305-0801, Japan",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "54b6fb81-79c1-4c23-b3a7-c760119ecfed",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1072833"
#       },
#       "full_name": "Apadula, N.",
#       "affiliations": [
#         {
#           "value": "Iowa State U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902893"
#           }
#         }
#       ],
#       "signature_block": "APADALn",
#       "raw_affiliations": [
#         {
#           "value": "Iowa State University, Ames, Iowa 50011, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "51b58be3-cb71-4cc2-930d-0855271be32f",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1883778"
#       },
#       "full_name": "Ayuso, C.",
#       "affiliations": [
#         {
#           "value": "Michigan U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903007"
#           }
#         }
#       ],
#       "signature_block": "ASc",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics, University of Michigan, Ann Arbor, Michigan 48109-1040, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "4e851756-dece-4148-88f7-4b979566eefa",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1017754"
#       },
#       "full_name": "Babintsev, V.",
#       "affiliations": [
#         {
#           "value": "Serpukhov, IHEP",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903194"
#           }
#         }
#       ],
#       "signature_block": "BABANTSAFv",
#       "raw_affiliations": [
#         {
#           "value": "IHEP Protvino, State Research Center of Russian Federation, Institute for High Energy Physics, Protvino, 142281, Russia",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "8ec2ded0-a5f5-4f12-bb8a-53382f79a2ae",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1017346"
#       },
#       "full_name": "Barish, K.N.",
#       "affiliations": [
#         {
#           "value": "UC, Riverside",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903304"
#           }
#         }
#       ],
#       "signature_block": "BARASk",
#       "raw_affiliations": [
#         {
#           "value": "University of California-Riverside, Riverside, California 92521, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "4e352500-9837-4c0b-9c88-7775694a308b",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1017147"
#       },
#       "full_name": "Bathe, S.",
#       "affiliations": [
#         {
#           "value": "Baruch Coll.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903785"
#           }
#         },
#         {
#           "value": "RIKEN BNL",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/907483"
#           }
#         }
#       ],
#       "signature_block": "BATs",
#       "raw_affiliations": [
#         {
#           "value": "Baruch College, City University of New York, New York, New York 10010, USA",
#           "source": "APS"
#         },
#         {
#           "value": "RIKEN BNL Research Center, Brookhaven National Laboratory, Upton, New York 11973-5000, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/02ex6cf31",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "4d6753ac-a5f1-4f50-8b8d-dec005681d32",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1057804"
#       },
#       "full_name": "Bazilevsky, A.",
#       "affiliations": [
#         {
#           "value": "Brookhaven",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902689"
#           }
#         }
#       ],
#       "signature_block": "BASALAFSCYa",
#       "raw_affiliations": [
#         {
#           "value": "Physics Department, Brookhaven National Laboratory, Upton, New York 11973-5000, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/02ex6cf31",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "4e69407f-d6a5-46f1-b16f-586bff0e55cd",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1070050"
#       },
#       "full_name": "Belmont, R.",
#       "affiliations": [
#         {
#           "value": "Colorado U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902748"
#           }
#         },
#         {
#           "value": "North Carolina U., Greensboro",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903079"
#           }
#         }
#       ],
#       "signature_block": "BALNADr",
#       "curated_relation": true,
#       "raw_affiliations": [
#         {
#           "value": "Physics and Astronomy Department, University of North Carolina at Greensboro, Greensboro, North Carolina 27412, USA",
#           "source": "APS"
#         },
#         {
#           "value": "University of Colorado, Boulder, Colorado 80309, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "e963b936-4292-4db5-ad45-383556b9690f",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1988075"
#       },
#       "full_name": "Berdnikov, A.",
#       "affiliations": [
#         {
#           "value": "St. Petersburg Polytechnic Inst.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903392"
#           }
#         }
#       ],
#       "signature_block": "BARDNACAVa",
#       "raw_affiliations": [
#         {
#           "value": "Saint Petersburg State Polytechnic University, St. Petersburg, 195251 Russia",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "ae1f9c68-aa58-4a37-94df-f62d2fe9dd3d",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1016696"
#       },
#       "full_name": "Berdnikov, Y.",
#       "affiliations": [
#         {
#           "value": "St. Petersburg Polytechnic Inst.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903392"
#           }
#         }
#       ],
#       "signature_block": "BARDNACAVy",
#       "raw_affiliations": [
#         {
#           "value": "Saint Petersburg State Polytechnic University, St. Petersburg, 195251 Russia",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "58fa6527-bc31-4779-acee-3c932ccbc1a1",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1918180"
#       },
#       "full_name": "Bichon, L.",
#       "affiliations": [
#         {
#           "value": "Vanderbilt U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903321"
#           }
#         }
#       ],
#       "signature_block": "BACANl",
#       "raw_affiliations": [
#         {
#           "value": "Vanderbilt University, Nashville, Tennessee 37235, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "82196fc6-dce3-44fd-8973-173acb99a47f",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1883780"
#       },
#       "full_name": "Blankenship, B.",
#       "affiliations": [
#         {
#           "value": "Vanderbilt U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903321"
#           }
#         }
#       ],
#       "signature_block": "BLANCANSAPb",
#       "raw_affiliations": [
#         {
#           "value": "Vanderbilt University, Nashville, Tennessee 37235, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "73fd3f4e-59a5-4d45-812b-8e74b8add194",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1068782"
#       },
#       "full_name": "Blau, D.S.",
#       "affiliations": [
#         {
#           "value": "Kurchatov Inst., Moscow",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902938"
#           }
#         },
#         {
#           "value": "Moscow Phys. Eng. Inst.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903032"
#           }
#         }
#       ],
#       "signature_block": "BLd",
#       "raw_affiliations": [
#         {
#           "value": "National Research Center \u201cKurchatov Institute\u201d, Moscow, 123098 Russia",
#           "source": "APS"
#         },
#         {
#           "value": "National Research Nuclear University, MEPhI, Moscow Engineering Physics Institute, Moscow, 115409, Russia",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "09febb5c-a24b-4b75-bd73-ef8681d73762",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1025940"
#       },
#       "full_name": "Boer, M.",
#       "affiliations": [
#         {
#           "value": "Los Alamos",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902968"
#           }
#         }
#       ],
#       "signature_block": "BARm",
#       "raw_affiliations": [
#         {
#           "value": "Los Alamos National Laboratory, Los Alamos, New Mexico 87545, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "4c803067-15da-4620-b675-6390f66c9824",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1070051"
#       },
#       "full_name": "Bok, J.S.",
#       "affiliations": [
#         {
#           "value": "New Mexico State U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903063"
#           }
#         }
#       ],
#       "signature_block": "BACj",
#       "raw_affiliations": [
#         {
#           "value": "New Mexico State University, Las Cruces, New Mexico 88003, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "85cbe31f-9618-47f3-bbdd-e320019aeb24",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1955487"
#       },
#       "full_name": "Borisov, V.",
#       "affiliations": [
#         {
#           "value": "St. Petersburg Polytechnic Inst.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903392"
#           }
#         }
#       ],
#       "signature_block": "BARASAVv",
#       "raw_affiliations": [
#         {
#           "value": "Saint Petersburg State Polytechnic University, St. Petersburg, 195251 Russia",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "ca2be1ca-7809-4a58-8d75-a929450e88be",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1057807"
#       },
#       "full_name": "Brooks, M.L.",
#       "affiliations": [
#         {
#           "value": "Los Alamos",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902968"
#           }
#         }
#       ],
#       "signature_block": "BRACm",
#       "raw_affiliations": [
#         {
#           "value": "Los Alamos National Laboratory, Los Alamos, New Mexico 87545, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "5e07502a-640d-4662-bee8-28fa613ac88e",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1291627"
#       },
#       "full_name": "Bryslawskyj, J.",
#       "affiliations": [
#         {
#           "value": "Baruch Coll.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903785"
#           }
#         },
#         {
#           "value": "UC, Riverside",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903304"
#           }
#         }
#       ],
#       "signature_block": "BRASLASCAJj",
#       "raw_affiliations": [
#         {
#           "value": "University of California-Riverside, Riverside, California 92521, USA",
#           "source": "APS"
#         },
#         {
#           "value": "Baruch College, City University of New York, New York, New York 10010, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "d3c5ea54-fe22-4efd-a1fa-4e2c8e4d62a7",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1057808"
#       },
#       "full_name": "Bumazhnov, V.",
#       "affiliations": [
#         {
#           "value": "Serpukhov, IHEP",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903194"
#           }
#         }
#       ],
#       "signature_block": "BANASHNAVv",
#       "raw_affiliations": [
#         {
#           "value": "IHEP Protvino, State Research Center of Russian Federation, Institute for High Energy Physics, Protvino, 142281, Russia",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "004a2721-49ce-4937-bdd9-05e31d8c610d",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1037866"
#       },
#       "full_name": "Butler, C.",
#       "affiliations": [
#         {
#           "value": "Georgia State U., Atlanta",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/1275736"
#           }
#         }
#       ],
#       "signature_block": "BATLARc",
#       "raw_affiliations": [
#         {
#           "value": "Georgia State University, Atlanta, Georgia 30303, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/03qt6ba18",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "cb4aaf99-bb87-4713-bfec-283d0f8d5f8e",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1068384"
#       },
#       "full_name": "Campbell, S.",
#       "affiliations": [
#         {
#           "value": "Nevis Labs, Columbia U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903060"
#           }
#         }
#       ],
#       "signature_block": "CANPBALs",
#       "raw_affiliations": [
#         {
#           "value": "Columbia University, New York, New York 10027 and Nevis Laboratories, Irvington, New York 10533, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "3c1d6f65-8051-44ad-86e2-a5d03e2c27be",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1068519"
#       },
#       "full_name": "Canoa Roman, V.",
#       "affiliations": [
#         {
#           "value": "SUNY, Stony Brook",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903237"
#           }
#         }
#       ],
#       "signature_block": "CANv",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Stony Brook University, SUNY, Stony Brook, New York 11794-3800, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "15396a9c-12a0-4d43-bfc1-9c1edbf033ae",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1057811"
#       },
#       "full_name": "Chiu, M.",
#       "affiliations": [
#         {
#           "value": "Brookhaven",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902689"
#           }
#         }
#       ],
#       "signature_block": "Cm",
#       "raw_affiliations": [
#         {
#           "value": "Physics Department, Brookhaven National Laboratory, Upton, New York 11973-5000, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/02ex6cf31",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "99fa51ef-1563-4c6c-9a3f-d891c29cedfc",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1055339"
#       },
#       "full_name": "Connors, M.",
#       "affiliations": [
#         {
#           "value": "Georgia State U., Atlanta",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/1275736"
#           }
#         },
#         {
#           "value": "RIKEN BNL",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/907483"
#           }
#         }
#       ],
#       "signature_block": "CANARm",
#       "raw_affiliations": [
#         {
#           "value": "Georgia State University, Atlanta, Georgia 30303, USA",
#           "source": "APS"
#         },
#         {
#           "value": "RIKEN BNL Research Center, Brookhaven National Laboratory, Upton, New York 11973-5000, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/03qt6ba18",
#           "schema": "ROR"
#         },
#         {
#           "value": "https://ror.org/02ex6cf31",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "70391d76-71ca-439a-98f8-385d5d4b9862",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1061278"
#       },
#       "full_name": "Corliss, R.",
#       "affiliations": [
#         {
#           "value": "SUNY, Stony Brook",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903237"
#           }
#         }
#       ],
#       "signature_block": "CARLr",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Stony Brook University, SUNY, Stony Brook, New York 11794-3800, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "56dbaddd-9ce9-41eb-8958-192f89deda0c",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1066700"
#       },
#       "full_name": "Corrales Morales, Y.",
#       "affiliations": [
#         {
#           "value": "Los Alamos",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902968"
#           }
#         }
#       ],
#       "signature_block": "MARALy",
#       "raw_affiliations": [
#         {
#           "value": "Los Alamos National Laboratory, Los Alamos, New Mexico 87545, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "f6e5777b-2f0a-457e-9b6d-477ec998107e",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1055923"
#       },
#       "full_name": "Csan\u00e1d, M.",
#       "affiliations": [
#         {
#           "value": "Eotvos U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902790"
#           }
#         }
#       ],
#       "signature_block": "CSANADm",
#       "curated_relation": true,
#       "raw_affiliations": [
#         {
#           "value": "ELTE, E\u00f6tv\u00f6s Lor\u00e1nd University, H-1117 Budapest, P\u00e1zm\u00e1ny P. s. 1/A, Hungary",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "1c02f4dd-a634-484c-91cf-a60beae7b668",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/2575625"
#       },
#       "full_name": "Cs\u00f6rgo, T.",
#       "affiliations": [
#         {
#           "value": "Karoly Robert U. Coll.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/1487784"
#           }
#         },
#         {
#           "value": "Wigner RCP, Budapest",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/1090092"
#           }
#         }
#       ],
#       "signature_block": "CSARGt",
#       "raw_affiliations": [
#         {
#           "value": "MATE, Institute of Technology, Laboratory of Femtoscopy, K\u00e1roly R\u00f3bert Campus, H-3200 Gy\u00f6ngy\u00f6s, M\u00e1trai \u00fat 36, Hungary",
#           "source": "APS"
#         },
#         {
#           "value": "Institute for Particle and Nuclear Physics, HUN-REN Wigner Research Centre for Physics, (HUN-REN Wigner RCP, RMI), H-1525 Budapest 114, POBox 49, Budapest, Hungary",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "55c6710d-60c1-468c-8724-cb8a9d37a3f9",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1344823"
#       },
#       "full_name": "Liu, L.D.",
#       "affiliations": [
#         {
#           "value": "Shanghai Jiao Tong U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/911458"
#           }
#         },
#         {
#           "value": "Shanghai Jiaotong U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/904740"
#           }
#         },
#         {
#           "value": "Peking U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903603"
#           }
#         }
#       ],
#       "signature_block": "Ll",
#       "raw_affiliations": [
#         {
#           "value": "Peking University, Beijing 100871, People\u2019s Republic of China",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "44d560d9-2320-452f-9b42-d88b5be82f7b",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1942567"
#       },
#       "full_name": "Danley, T.W.",
#       "affiliations": [
#         {
#           "value": "UNAM, Inst. Astron.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/908050"
#           }
#         },
#         {
#           "value": "Ohio U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903093"
#           }
#         }
#       ],
#       "signature_block": "DANLYt",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Ohio University, Athens, Ohio 45701, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "d3052d1c-90bc-4ef2-b4b9-5cf4d2585882",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1191678"
#       },
#       "full_name": "Daugherity, M.S.",
#       "affiliations": [
#         {
#           "value": "Abilene Christian U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/904558"
#           }
#         }
#       ],
#       "signature_block": "DAGARATYm",
#       "raw_affiliations": [
#         {
#           "value": "Abilene Christian University, Abilene, Texas 79699, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "0efb0847-1ec9-45a1-8af2-42a16c2160b1",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1012351"
#       },
#       "full_name": "David, G.",
#       "affiliations": [
#         {
#           "value": "Brookhaven",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902689"
#           }
#         },
#         {
#           "value": "SUNY, Stony Brook",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903237"
#           }
#         }
#       ],
#       "signature_block": "DAVADg",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Stony Brook University, SUNY, Stony Brook, New York 11794-3800, USA",
#           "source": "APS"
#         },
#         {
#           "value": "Physics Department, Brookhaven National Laboratory, Upton, New York 11973-5000, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/02ex6cf31",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "fbfc1b01-3689-48dc-b149-810957056a1c",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1341576"
#       },
#       "full_name": "Dean, C.T.",
#       "affiliations": [
#         {
#           "value": "Los Alamos",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902968"
#           }
#         }
#       ],
#       "signature_block": "DANc",
#       "raw_affiliations": [
#         {
#           "value": "Los Alamos National Laboratory, Los Alamos, New Mexico 87545, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "7e3b4b10-ee70-4535-b846-469750958d43",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1942568"
#       },
#       "full_name": "DeBlasio, K.",
#       "affiliations": [
#         {
#           "value": "New Mexico U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903064"
#           }
#         }
#       ],
#       "signature_block": "DABLASk",
#       "raw_affiliations": [
#         {
#           "value": "University of New Mexico, Albuquerque, New Mexico 87131, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "ebf65ea5-a61a-427b-9764-b289da245f8e",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1033037"
#       },
#       "full_name": "Dehmelt, K.",
#       "affiliations": [
#         {
#           "value": "SUNY, Stony Brook",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903237"
#           }
#         }
#       ],
#       "signature_block": "DANALTk",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Stony Brook University, SUNY, Stony Brook, New York 11794-3800, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "09465898-5159-45ff-8a16-394d5c3f7ab9",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1027680"
#       },
#       "full_name": "Denisov, A.",
#       "affiliations": [
#         {
#           "value": "Serpukhov, IHEP",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903194"
#           }
#         }
#       ],
#       "signature_block": "DANASAVa",
#       "raw_affiliations": [
#         {
#           "value": "IHEP Protvino, State Research Center of Russian Federation, Institute for High Energy Physics, Protvino, 142281, Russia",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "eb1fde03-2cf1-4caf-b683-f35a694665a1",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1011951"
#       },
#       "full_name": "Deshpande, A.",
#       "affiliations": [
#         {
#           "value": "RIKEN BNL",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/907483"
#           }
#         },
#         {
#           "value": "SUNY, Stony Brook",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903237"
#           }
#         }
#       ],
#       "signature_block": "DASPANDa",
#       "curated_relation": true,
#       "raw_affiliations": [
#         {
#           "value": "RIKEN BNL Research Center, Brookhaven National Laboratory, Upton, New York 11973-5000, USA",
#           "source": "APS"
#         },
#         {
#           "value": "Department of Physics and Astronomy, Stony Brook University, SUNY, Stony Brook, New York 11794-3800, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/02ex6cf31",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "4dc177ca-5f04-4b75-b110-163b3e36d9e8",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1027681"
#       },
#       "full_name": "Desmond, E.J.",
#       "affiliations": [
#         {
#           "value": "Brookhaven",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902689"
#           }
#         }
#       ],
#       "signature_block": "DASNADe",
#       "raw_affiliations": [
#         {
#           "value": "Physics Department, Brookhaven National Laboratory, Upton, New York 11973-5000, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/02ex6cf31",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "e172e5e5-a6fb-4ffb-90f7-7068c0955a81",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/2057353"
#       },
#       "full_name": "Doomra, V.",
#       "affiliations": [
#         {
#           "value": "SUNY, Stony Brook",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903237"
#           }
#         }
#       ],
#       "signature_block": "DANRv",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Stony Brook University, SUNY, Stony Brook, New York 11794-3800, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "f3c7cb83-0cff-4c3b-a838-266c5cbd3f0d",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1251467"
#       },
#       "full_name": "Do, J.H.",
#       "affiliations": [
#         {
#           "value": "IPAP, Seoul",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/909001"
#           }
#         },
#         {
#           "value": "Yonsei U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903829"
#           }
#         }
#       ],
#       "signature_block": "Dj",
#       "raw_affiliations": [
#         {
#           "value": "Yonsei University, IPAP, Seoul 120-749, Korea",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "038804fe-9e78-472f-8b9e-43942b94b3f1",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1011415"
#       },
#       "full_name": "Drees, A.",
#       "affiliations": [
#         {
#           "value": "SUNY, Stony Brook",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903237"
#           }
#         }
#       ],
#       "signature_block": "DRYa",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Stony Brook University, SUNY, Stony Brook, New York 11794-3800, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "1c8f0f8a-af67-4cff-b950-8573f22ecd3b",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1011416"
#       },
#       "full_name": "Drees, K.A.",
#       "affiliations": [
#         {
#           "value": "Brookhaven",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902689"
#           }
#         }
#       ],
#       "signature_block": "DRYk",
#       "raw_affiliations": [
#         {
#           "value": "Collider-Accelerator Department, Brookhaven National Laboratory, Upton, New York 11973-5000, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/02ex6cf31",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "49816b27-6938-444d-9c8b-69ea362b2119",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1328243"
#       },
#       "full_name": "Dumancic, M.",
#       "affiliations": [
#         {
#           "value": "Weizmann Inst.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903342"
#           }
#         }
#       ],
#       "signature_block": "DANANCACm",
#       "raw_affiliations": [
#         {
#           "value": "Weizmann Institute, Rehovot 76100, Israel",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "1090c9d3-3606-4076-a768-6ae2bc5baeea",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1070071"
#       },
#       "full_name": "Durham, J.M.",
#       "affiliations": [
#         {
#           "value": "Los Alamos",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902968"
#           }
#         }
#       ],
#       "signature_block": "DARANj",
#       "raw_affiliations": [
#         {
#           "value": "Los Alamos National Laboratory, Los Alamos, New Mexico 87545, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "412682e6-a988-467d-8b38-15c4fdb131cd",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1057818"
#       },
#       "full_name": "Durum, A.",
#       "affiliations": [
#         {
#           "value": "Serpukhov, IHEP",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903194"
#           }
#         }
#       ],
#       "signature_block": "DARANa",
#       "raw_affiliations": [
#         {
#           "value": "IHEP Protvino, State Research Center of Russian Federation, Institute for High Energy Physics, Protvino, 142281, Russia",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "716a6609-ae2d-4146-b688-3c9bdd73fcbc",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/2026176"
#       },
#       "full_name": "Elder, T.",
#       "affiliations": [
#         {
#           "value": "Georgia State U., Atlanta",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/1275736"
#           }
#         }
#       ],
#       "signature_block": "ELDARt",
#       "raw_affiliations": [
#         {
#           "value": "Georgia State University, Atlanta, Georgia 30303, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/03qt6ba18",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "03421284-88eb-4b21-a8c9-78492ef4892c",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1010706"
#       },
#       "full_name": "Enokizono, A.",
#       "affiliations": [
#         {
#           "value": "Nishina Ctr., RIKEN",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/911022"
#           }
#         },
#         {
#           "value": "Rikkyo U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903157"
#           }
#         }
#       ],
#       "signature_block": "ENACASANa",
#       "raw_affiliations": [
#         {
#           "value": "RIKEN Nishina Center for Accelerator-Based Science, Wako, Saitama 351-0198, Japan",
#           "source": "APS"
#         },
#         {
#           "value": "Physics Department, Rikkyo University, 3-34-1 Nishi-Ikebukuro, Toshima, Tokyo 171-8501, Japan",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "8479d3fd-67a8-497c-9762-5826ad299ef5",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1325724"
#       },
#       "full_name": "Esha, R.",
#       "affiliations": [
#         {
#           "value": "SUNY, Stony Brook",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903237"
#           }
#         }
#       ],
#       "signature_block": "ESr",
#       "curated_relation": true,
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Stony Brook University, SUNY, Stony Brook, New York 11794-3800, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "7c7d71dd-a7c6-4c7c-8cb8-a174cdeddee1",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1021739"
#       },
#       "full_name": "Fadem, B.",
#       "affiliations": [
#         {
#           "value": "Penn State U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903125"
#           }
#         }
#       ],
#       "signature_block": "FADANb",
#       "raw_affiliations": [
#         {
#           "value": "Muhlenberg College, Allentown, Pennsylvania 18104-5586, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "d92fe1ae-d161-4f77-80d2-525a41466b8a",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1957689"
#       },
#       "full_name": "Fan, W.",
#       "affiliations": [
#         {
#           "value": "SUNY, Stony Brook",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903237"
#           }
#         }
#       ],
#       "signature_block": "FANw",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Stony Brook University, SUNY, Stony Brook, New York 11794-3800, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "ddea8a0b-c0a5-4b71-8d39-1631cc5b994b",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1054541"
#       },
#       "full_name": "Feege, N.",
#       "affiliations": [
#         {
#           "value": "SUNY, Stony Brook",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903237"
#           }
#         }
#       ],
#       "signature_block": "FAGn",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Stony Brook University, SUNY, Stony Brook, New York 11794-3800, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "ab87b0ab-42fd-4fb5-9d96-a244dde28fd4",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1233260"
#       },
#       "full_name": "Finger Jr, M.",
#       "affiliations": [
#         {
#           "value": "Charles U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902727"
#           }
#         }
#       ],
#       "signature_block": "FANGARm",
#       "raw_affiliations": [
#         {
#           "value": "Charles University, Faculty of Mathematics and Physics, 180 00 Troja, Prague, Czech Republic"
#         }
#       ]
#     },
#     {
#       "uuid": "03c79934-d461-4cff-ae3c-43fa565caa63",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1233260"
#       },
#       "full_name": "Finger, M.",
#       "affiliations": [
#         {
#           "value": "Charles U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902727"
#           }
#         }
#       ],
#       "signature_block": "FANGARm",
#       "raw_affiliations": [
#         {
#           "value": "Charles University, Faculty of Mathematics and Physics, 180 00 Troja, Prague, Czech Republic"
#         }
#       ]
#     },
#     {
#       "uuid": "2f897c89-b0d3-4e49-8935-c21d60884e7d",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1962855"
#       },
#       "full_name": "Firak, D.",
#       "affiliations": [
#         {
#           "value": "Debrecen U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/911686"
#           }
#         },
#         {
#           "value": "SUNY, Stony Brook",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903237"
#           }
#         }
#       ],
#       "signature_block": "FARACd",
#       "raw_affiliations": [
#         {
#           "value": "Debrecen University, H-4010 Debrecen, Egyetem t\u00e9r 1, Hungary",
#           "source": "APS"
#         },
#         {
#           "value": "Department of Physics and Astronomy, Stony Brook University, SUNY, Stony Brook, New York 11794-3800, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "94fd123e-d4d1-474d-b5fa-8bceb3eb0ccb",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1876083"
#       },
#       "full_name": "Fitzgerald, D.",
#       "affiliations": [
#         {
#           "value": "Michigan U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903007"
#           }
#         }
#       ],
#       "signature_block": "FATSGARALDd",
#       "curated_relation": true,
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics, University of Michigan, Ann Arbor, Michigan 48109-1040, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "bc192d7d-f4c7-48ff-ab07-a47941ba07b6",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1057821"
#       },
#       "full_name": "Fokin, S.L.",
#       "affiliations": [
#         {
#           "value": "Kurchatov Inst., Moscow",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902938"
#           }
#         }
#       ],
#       "signature_block": "FACANs",
#       "raw_affiliations": [
#         {
#           "value": "National Research Center \u201cKurchatov Institute\u201d, Moscow, 123098 Russia",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "6e5e956c-a1f7-455a-b2e2-60f82866683c",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1021290"
#       },
#       "full_name": "Frantz, J.E.",
#       "affiliations": [
#         {
#           "value": "UNAM, Inst. Astron.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/908050"
#           }
#         },
#         {
#           "value": "Ohio U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903093"
#           }
#         }
#       ],
#       "signature_block": "FRADj",
#       "raw_affiliations": [
#         {
#           "value": "Department of Physics and Astronomy, Ohio University, Athens, Ohio 45701, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "479ad41f-5ef2-4e8e-993c-03e97bfc4f6a",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1009537"
#       },
#       "full_name": "Franz, A.",
#       "affiliations": [
#         {
#           "value": "Brookhaven",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902689"
#           }
#         }
#       ],
#       "signature_block": "FRANa",
#       "raw_affiliations": [
#         {
#           "value": "Physics Department, Brookhaven National Laboratory, Upton, New York 11973-5000, USA",
#           "source": "APS"
#         }
#       ],
#       "affiliations_identifiers": [
#         {
#           "value": "https://ror.org/02ex6cf31",
#           "schema": "ROR"
#         }
#       ]
#     },
#     {
#       "uuid": "bdcf9065-6b02-4bfa-b71f-1470d9e4220d",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1057822"
#       },
#       "full_name": "Frawley, A.D.",
#       "affiliations": [
#         {
#           "value": "Florida State U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/902803"
#           }
#         }
#       ],
#       "signature_block": "FRALYa",
#       "raw_affiliations": [
#         {
#           "value": "Florida State University, Tallahassee, Florida 32306, USA",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "e74ca67c-5fb2-4365-9551-8d2a886ed9d7",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1274199"
#       },
#       "full_name": "Fukuda, Y.",
#       "affiliations": [
#         {
#           "value": "Tsukuba U.",
#           "record": {
#             "$ref": "https://inspirehep.net/api/institutions/903293"
#           }
#         }
#       ],
#       "signature_block": "FACADy",
#       "raw_affiliations": [
#         {
#           "value": "Tomonaga Center for the History of the Universe, University of Tsukuba, Tsukuba, Ibaraki 305, Japan",
#           "source": "APS"
#         }
#       ]
#     },
#     {
#       "uuid": "d32385c0-be8b-416e-9498-7336c86ef82e",
#       "record": {
#         "$ref": "https://inspirehep.net/api/authors/1292320"
#       },
#       "full_name": "Gal, C.",
#       "affiliations": [
#         {
# ...
#           "schema": "JATS",
#           "source": "APS"
#         }
#       ],
#       "reference": {
#         "dois": [
#           "10.1103/PhysRevC.104.054902"
#         ],
#         "label": "54",
#         "title": {
#           "title": "Examination of the universal behavior of the "
#         },
#         "authors": [
#           {
#             "full_name": "Ren, Y.",
#             "inspire_role": "author"
#           },
#           {
#             "full_name": "Drees, A.",
#             "inspire_role": "author"
#           }
#         ],
#         "publication_info": {
#           "year": 2021,
#           "artid": "054902",
#           "journal_title": "Phys.Rev.C",
#           "journal_record": {
#             "$ref": "https://inspirehep.net/api/journals/1613969"
#           },
#           "journal_volume": "104"
#         }
#       }
#     },
#     {
#       "record": {
#         "$ref": "https://inspirehep.net/api/literature/1296308"
#       },
#       "raw_refs": [
#         {
#           "value": "<ref id=\"c55\"><label>[55]</label><mixed-citation publication-type=\"journal\"><object-id>55</object-id><person-group person-group-type=\"author\"><string-name>A. Adare</string-name> <etal/> (<collab>PHENIX Collaboration</collab>)</person-group>, <article-title>Centrality dependence of low-momentum direct-photon production in <inline-formula><math display=\"inline\"><mrow><mi>Au</mi><mo stretchy=\"false\">+</mo><mi>Au</mi></mrow></math></inline-formula> collisions at <inline-formula><math display=\"inline\"><msqrt><msub><mi>s</mi><mrow><mi>N</mi><mi>N</mi></mrow></msub></msqrt><mo>=</mo><mn>200</mn><mtext>\u2009</mtext><mtext>\u2009</mtext><mi>GeV</mi></math></inline-formula></article-title>, <source>Phys. Rev. C</source> <volume>91</volume>, <page-range>064904</page-range> (<year>2015</year>).<pub-id pub-id-type=\"coden\">PRVCAN</pub-id><issn>0556-2813</issn><pub-id pub-id-type=\"doi\" specific-use=\"suppress-display\">10.1103/PhysRevC.91.064904</pub-id></mixed-citation></ref>",
#           "schema": "JATS",
#           "source": "APS"
#         }
#       ],
#       "reference": {
#         "dois": [
#           "10.1103/PhysRevC.91.064904"
#         ],
#         "label": "55",
#         "title": {
#           "title": "Centrality dependence of low-momentum direct-photon production in "
#         },
#         "authors": [
#           {
#             "full_name": "Adare, A.",
#             "inspire_role": "author"
#           }
#         ],
#         "publication_info": {
#           "year": 2015,
#           "artid": "064904",
#           "journal_title": "Phys.Rev.C",
#           "journal_record": {
#             "$ref": "https://inspirehep.net/api/journals/1613969"
#           },
#           "journal_volume": "91"
#         }
#       }
#     },
#     {
#       "raw_refs": [
#         {
#           "value": "<ref id=\"c56\"><label>[56]</label><mixed-citation publication-type=\"thesis\"><object-id>56</object-id><person-group person-group-type=\"author\"><string-name>N. Ramasubramanian</string-name></person-group>, <article-title>Validation of the Glauber model for centrality determination in small system collisions</article-title>, Ph.D. thesis, <institution>Stony Brook University</institution>, <year>2021</year>.</mixed-citation></ref>",
#           "schema": "JATS",
#           "source": "APS"
#         }
#       ],
#       "reference": {
#         "misc": [
#           "Ph.D. thesis, Stony Brook University"
#         ],
#         "label": "56",
#         "title": {
#           "title": "Validation of the Glauber model for centrality determination in small system collisions"
#         },
#         "authors": [
#           {
#             "full_name": "Ramasubramanian, N.",
#             "inspire_role": "author"
#           }
#         ],
#         "publication_info": {
#           "year": 2021
#         }
#       }
#     },
#     {
#       "raw_refs": [
#         {
#           "value": "<ref id=\"c57\"><label>[57]</label><mixed-citation publication-type=\"supplemental-material\"><object-id>57</object-id>See Supplemental Material at <ext-link ext-link-type=\"uri\" href=\"http://link.aps.org/supplemental/10.1103/PhysRevLett.134.022302\">http://link.aps.org/supplemental/10.1103/PhysRevLett.134.022302</ext-link>, which includes Refs.\u00a0[58\u201360], for detailed explanations for the specialists on breakdown of the systematic uncertainties, their correlations and propagation, as well as cancelation in ratios.</mixed-citation></ref>",
#           "schema": "JATS",
#           "source": "APS"
#         }
#       ],
#       "reference": {
#         "misc": [
#           "See Supplemental Material at http://link.aps.org/supplemental/10.1103/PhysRevLett.134.022302, which includes Refs.\u00a0[58\u201360], for detailed explanations for the specialists on breakdown of the systematic uncertainties, their correlations and propagation, as well as cancelation in ratios"
#         ],
#         "label": "57"
#       }
#     },
#     {
#       "record": {
#         "$ref": "https://inspirehep.net/api/literature/1946529"
#       },
#       "raw_refs": [
#         {
#           "value": "<ref id=\"c58\"><label>[58]</label><mixed-citation publication-type=\"journal\"><object-id>58</object-id><person-group person-group-type=\"author\"><string-name>M.\u2009R. Aguilar</string-name>, <string-name>Z. Chang</string-name>, <string-name>R.\u2009K. Elayavalli</string-name>, <string-name>R. Fatemi</string-name>, <string-name>Y. He</string-name>, <string-name>Y. Ji</string-name>, <string-name>D. Kalinkin</string-name>, <string-name>M. Kelsey</string-name>, <string-name>I. Mooney</string-name>, and <string-name>V. Verkest</string-name></person-group>, <article-title><sc>pythia</sc>8 underlying event tune for RHIC energies</article-title>, <source>Phys. Rev. D</source> <volume>105</volume>, <page-range>016011</page-range> (<year>2022</year>).<pub-id pub-id-type=\"coden\">PRVDAQ</pub-id><issn>2470-0010</issn><pub-id pub-id-type=\"doi\" specific-use=\"suppress-display\">10.1103/PhysRevD.105.016011</pub-id></mixed-citation></ref>",
#           "schema": "JATS",
#           "source": "APS"
#         }
#       ],
#       "reference": {
#         "dois": [
#           "10.1103/PhysRevD.105.016011"
#         ],
#         "label": "58",
#         "title": {
#           "title": "8 underlying event tune for RHIC energies"
#         },
#         "authors": [
#           {
#             "full_name": "Aguilar, M.R.",
#             "inspire_role": "author"
#           },
#           {
#             "full_name": "Chang, Z.",
#             "inspire_role": "author"
#           },
#           {
#             "full_name": "Elayavalli, R.K.",
#             "inspire_role": "author"
#           },
#           {
#             "full_name": "Fatemi, R.",
#             "inspire_role": "author"
#           },
#           {
#             "full_name": "He, Y.",
#             "inspire_role": "author"
#           },
#           {
#             "full_name": "Ji, Y.",
#             "inspire_role": "author"
#           },
#           {
#             "full_name": "Kalinkin, D.",
#             "inspire_role": "author"
#           },
#           {
#             "full_name": "Kelsey, M.",
#             "inspire_role": "author"
#           },
#           {
#             "full_name": "Mooney, I.",
#             "inspire_role": "author"
#           },
#           {
#             "full_name": "Verkest, V.",
#             "inspire_role": "author"
#           }
#         ],
#         "publication_info": {
#           "year": 2022,
#           "artid": "016011",
#           "journal_title": "Phys.Rev.D",
#           "journal_record": {
#             "$ref": "https://inspirehep.net/api/journals/1613970"
#           },
#           "journal_volume": "105"
#         }
#       }
#     },
#     {
#       "record": {
#         "$ref": "https://inspirehep.net/api/literature/1394434"
#       },
#       "raw_refs": [
#         {
#           "value": "<ref id=\"c59\"><label>[59]</label><mixed-citation publication-type=\"journal\"><object-id>59</object-id><person-group person-group-type=\"author\"><string-name>A. Adare</string-name> <etal/> (<collab>PHENIX Collaboration</collab>)</person-group>, <article-title>Scaling properties of fractional momentum loss of high-<inline-formula><math display=\"inline\"><msub><mi>p</mi><mi>T</mi></msub></math></inline-formula> hadrons in nucleus-nucleus collisions at <inline-formula><math display=\"inline\"><msqrt><msub><mi>s</mi><mrow><mi>N</mi><mi>N</mi></mrow></msub></msqrt></math></inline-formula> from 62.4\u00a0GeV to 2.76\u00a0TeV</article-title>, <source>Phys. Rev. C</source> <volume>93</volume>, <page-range>024911</page-range> (<year>2016</year>).<pub-id pub-id-type=\"coden\">PRVCAN</pub-id><issn>2469-9985</issn><pub-id pub-id-type=\"doi\" specific-use=\"suppress-display\">10.1103/PhysRevC.93.024911</pub-id></mixed-citation></ref>",
#           "schema": "JATS",
#           "source": "APS"
#         }
#       ],
#       "reference": {
#         "dois": [
#           "10.1103/PhysRevC.93.024911"
#         ],
#         "label": "59",
#         "title": {
#           "title": "Scaling properties of fractional momentum loss of high-"
#         },
#         "authors": [
#           {
#             "full_name": "Adare, A.",
#             "inspire_role": "author"
#           }
#         ],
#         "publication_info": {
#           "year": 2016,
#           "artid": "024911",
#           "journal_title": "Phys.Rev.C",
#           "journal_record": {
#             "$ref": "https://inspirehep.net/api/journals/1613969"
#           },
#           "journal_volume": "93"
#         }
#       }
#     },
#     {
#       "record": {
#         "$ref": "https://inspirehep.net/api/literature/627894"
#       },
#       "raw_refs": [
#         {
#           "value": "<ref id=\"c60\"><label>[60]</label><mixed-citation publication-type=\"journal\"><object-id>60</object-id><person-group person-group-type=\"author\"><string-name>S. Adler</string-name> <etal/> (<collab>PHENIX Collaboration</collab>)</person-group>, <article-title>PHENIX on-line and off-line computing</article-title>, <source>Nucl. Instrum. Methods Phys. Res., Sect. A</source> <volume>499</volume>, <page-range>593</page-range> (<year>2003</year>).<pub-id pub-id-type=\"coden\">NIMAER</pub-id><issn>0168-9002</issn><pub-id pub-id-type=\"doi\" specific-use=\"suppress-display\">10.1016/S0168-9002(02)01958-7</pub-id></mixed-citation></ref>",
#           "schema": "JATS",
#           "source": "APS"
#         }
#       ],
#       "reference": {
#         "dois": [
#           "10.1016/S0168-9002(02)01958-7"
#         ],
#         "label": "60",
#         "title": {
#           "title": "PHENIX on-line and off-line computing"
#         },
#         "authors": [
#           {
#             "full_name": "Adler, S.",
#             "inspire_role": "author"
#           }
#         ],
#         "publication_info": {
#           "year": 2003,
#           "artid": "593",
#           "page_start": "593",
#           "journal_title": "Nucl.Instrum.Meth.A",
#           "journal_record": {
#             "$ref": "https://inspirehep.net/api/journals/1613981"
#           },
#           "journal_volume": "499"
#         }
#       }
#     },
#     {
#       "record": {
#         "$ref": "https://inspirehep.net/api/literature/1115828"
#       },
#       "raw_refs": [
#         {
#           "value": "<ref id=\"c61\"><label>[61]</label><mixed-citation publication-type=\"journal\"><object-id>61</object-id><person-group person-group-type=\"author\"><string-name>A. Adare</string-name> <etal/> (<collab>PHENIX Collaboration</collab>)</person-group>, <article-title>Direct-photon production in <inline-formula><math display=\"inline\"><mi>p</mi><mo>+</mo><mi>p</mi></math></inline-formula> collisions at <inline-formula><math display=\"inline\"><msqrt><mi>s</mi></msqrt><mo>=</mo><mn>200</mn><mtext>\u2009</mtext><mtext>\u2009</mtext><mi>GeV</mi></math></inline-formula> at midrapidity</article-title>, <source>Phys. Rev. D</source> <volume>86</volume>, <page-range>072008</page-range> (<year>2012</year>).<pub-id pub-id-type=\"coden\">PRVDAQ</pub-id><issn>1550-7998</issn><pub-id pub-id-type=\"doi\" specific-use=\"suppress-display\">10.1103/PhysRevD.86.072008</pub-id></mixed-citation></ref>",
#           "schema": "JATS",
#           "source": "APS"
#         }
#       ],
#       "reference": {
#         "dois": [
#           "10.1103/PhysRevD.86.072008"
#         ],
#         "label": "61",
#         "title": {
#           "title": "Direct-photon production in "
#         },
#         "authors": [
#           {
#             "full_name": "Adare, A.",
#             "inspire_role": "author"
#           }
#         ],
#         "publication_info": {
#           "year": 2012,
#           "artid": "072008",
#           "journal_title": "Phys.Rev.D",
#           "journal_record": {
#             "$ref": "https://inspirehep.net/api/journals/1613970"
#           },
#           "journal_volume": "86"
#         }
#       }
#     },
#     {
#       "record": {
#         "$ref": "https://inspirehep.net/api/literature/1126017"
#       },
#       "raw_refs": [
#         {
#           "value": "<ref id=\"c62\"><label>[62]</label><mixed-citation publication-type=\"journal\"><object-id>62</object-id><person-group person-group-type=\"author\"><string-name>A. Adare</string-name> <etal/> (<collab>PHENIX Collaboration</collab>)</person-group>, <article-title>Direct photon production in <inline-formula><math display=\"inline\"><mrow><mi>d</mi><mo>+</mo><mi>Au</mi></mrow></math></inline-formula> collisions at <inline-formula><math display=\"inline\"><mrow><msqrt><mrow><msub><mrow><mi>s</mi></mrow><mrow><mi>N</mi><mi>N</mi></mrow></msub></mrow></msqrt><mo>=</mo><mn>200</mn><mtext>\u2009</mtext><mtext>\u2009</mtext><mi>GeV</mi></mrow></math></inline-formula></article-title>, <source>Phys. Rev. C</source> <volume>87</volume>, <page-range>054907</page-range> (<year>2013</year>).<pub-id pub-id-type=\"coden\">PRVCAN</pub-id><issn>0556-2813</issn><pub-id pub-id-type=\"doi\" specific-use=\"suppress-display\">10.1103/PhysRevC.87.054907</pub-id></mixed-citation></ref>",
#           "schema": "JATS",
#           "source": "APS"
#         }
#       ],
#       "reference": {
#         "dois": [
#           "10.1103/PhysRevC.87.054907"
#         ],
#         "label": "62",
#         "title": {
#           "title": "Direct photon production in "
#         },
#         "authors": [
#           {
#             "full_name": "Adare, A.",
#             "inspire_role": "author"
#           }
#         ],
#         "publication_info": {
#           "year": 2013,
#           "artid": "054907",
#           "journal_title": "Phys.Rev.C",
#           "journal_record": {
#             "$ref": "https://inspirehep.net/api/journals/1613969"
#           },
#           "journal_volume": "87"
#         }
#       }
#     }
#   ],
#   "public_notes": [
#     {
#       "value": "279 authors from 69 institutions, 8 pages, 3 figures, v2 is version\n accepted for publication in Physical Review Letters. HEPdata tables for the\n points plotted in figures for this and previous PHENIX publications are (or\n will be) publicly available at http://www.phenix.bnl.gov/papers.html",
#       "source": "arXiv"
#     }
#   ],
#   "arxiv_eprints": [
#     {
#       "value": "2303.12899",
#       "categories": [
#         "nucl-ex"
#       ]
#     }
#   ],
#   "document_type": [
#     "article"
#   ],
#   "preprint_date": "2023-03-22",
#   "collaborations": [
#     {
#       "value": "PHENIX",
#       "record": {
#         "$ref": "https://inspirehep.net/api/experiments/1108852"
#       }
#     }
#   ],
#   "control_number": 2645172,
#   "number_of_pages": 8,
#   "inspire_categories": [
#     {
#       "term": "Experiment-Nucl",
#       "source": "arxiv"
#     }
#   ],
#   "accelerator_experiments": [
#     {
#       "record": {
#         "$ref": "https://inspirehep.net/api/experiments/1108852"
#       },
#       "legacy_name": "BNL-RHIC-PHENIX"
#     },
#     {
#       "record": {
#         "$ref": "https://inspirehep.net/api/experiments/1108852"
#       },
#       "legacy_name": "BNL-RHIC-PHENIX",
#       "curated_relation": true
#     }
#   ],
#   "external_system_identifiers": [
#     {
#       "value": "hal-04060639",
#       "schema": "HAL"
#     },
#     {
#       "value": "ins2645172",
#       "schema": "HEPDATA"
#     }
#   ]
# }

# %%
# Load the two CSV databases
all_df = pd.read_csv("authors_sbu_since2023.csv")
sel_df = pd.read_csv("selected_authors_sbu_since2023.csv")

# Convert DOI strings to sets for easy comparison
def parse_dois(doi_str):
    if pd.isna(doi_str):
        return set()
    return set(d.strip() for d in str(doi_str).split(";") if d.strip())

all_df["DOI_set"] = all_df["DOIs"].apply(parse_dois)
sel_df["DOI_set"] = sel_df["DOIs"].apply(parse_dois)

# Convert to dicts keyed by AuthorKey for fast lookup
all_dict = all_df.set_index("AuthorKey")["DOI_set"].to_dict()
sel_dict = sel_df.set_index("AuthorKey")["DOI_set"].to_dict()

# Compare for each selected author
missing_records = []
for author_key, sel_dois in sel_dict.items():
    all_dois = all_dict.get(author_key, set())
    missing = all_dois - sel_dois
    if missing:
        missing_records.append({
            "AuthorKey": author_key,
            "Missing_Count": len(missing),
            "Missing_DOIs": "; ".join(sorted(missing))
        })

missing_df = pd.DataFrame(missing_records).sort_values("Missing_Count", ascending=False)
missing_df.to_csv("missing_articles_by_author.csv", index=False)

print(f"✅ Saved comparison: {len(missing_df)} authors have missing articles.")
print(missing_df.head(20))
# Out:
# ✅ Saved comparison: 73 authors have missing articles.
#         AuthorKey  Missing_Count  \
# 54          sun_c             36
# 4     deshpande_a             23
# 68     bernauer_j             21
# 71        cline_e             18
# 2          park_s             12
# 72        datta_j              8
# 37       mondal_m              4
# 7          esha_r              4
# 11      dehmelt_k              4
# 13       doomra_v              3
# 1           gal_c              3
# 9          garg_p              3
# 23  khachatryan_v              3
# 60         chen_c              2
# 8         firak_d              2
# 6         david_g              2
# 66          wei_r              1
# 44       cronin_n              1
# 45    cervantes_r              1
# 46        dixit_d              1
#
#                                          Missing_DOIs
# 54  10.1007/JHEP06(2023)176; 10.1007/JHEP10(2024)1...
# 4   10.1007/s41781-024-00113-4; 10.1016/j.nuclphys...
# 68  10.1007/s41781-024-00113-4; 10.1016/j.nima.202...
# 71  10.1007/s41781-024-00113-4; 10.1016/j.nima.202...
# 2   10.1016/j.nima.2022.167506; 10.1016/j.nuclphys...
# 72  10.1016/j.nima.2024.169920; 10.1016/j.nima.202...
# 37  10.1007/JHEP06(2023)176; 10.1038/s41586-022-05...
# 7   10.1007/JHEP06(2023)176; 10.22323/1.438.0068; ...
# 11  10.1016/j.ppnp.2023.104032; 10.1088/1748-0221/...
# 13  10.1007/978-981-97-0289-3_33; 10.1051/epjconf/...
# 1   10.1016/j.nima.2022.167506; 10.1103/PhysRevC.1...
# 9   10.1088/1748-0221/18/07/C07012; 10.1088/1748-0...
# 23  10.1016/j.nuclphysa.2023.122655; 10.1103/31xz-...
# 60  10.1103/PhysRevA.107.023117; 10.5506/APhysPolB...
# 8   10.1051/epjconf/202429611012; 10.5506/APhysPol...
# 6   10.1140/epjc/s10052-023-11885-1; 10.5506/APhys...
# 66                      10.5506/APhysPolBSupp.16.1-A7
# 44                      10.5506/APhysPolBSupp.16.1-A7
# 45                      10.5506/APhysPolBSupp.16.1-A7
# 46                      10.5506/APhysPolBSupp.16.1-A7

# %%
author = "drees_a"
all_dois = all_dict.get(author, set())
sel_dois = sel_dict.get(author, set())
missing = all_dois - sel_dois

print(f"Missing DOIs for {author}:")
for d in sorted(missing):
    print("  ", d)
# Out:
# Missing DOIs for drees_a:
#    10.5506/APhysPolBSupp.16.1-A7
